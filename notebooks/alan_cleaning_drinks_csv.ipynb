# %%
import pandas as pd

# %%
drinks_df = pd.read_csv('../raw_data/all_drinks.csv')

# %%
drinks_df = drinks_df.drop(columns=['dateModified','idDrink','strAlcoholic'])

# %%
drinks_df.columns
# Out:
# Index(['Unnamed: 0', 'strDrink', 'strCategory', 'strDrinkThumb', 'strGlass',
#        'strIBA', 'strIngredient1', 'strIngredient10', 'strIngredient11',
#        'strIngredient12', 'strIngredient13', 'strIngredient14',
#        'strIngredient15', 'strIngredient2', 'strIngredient3', 'strIngredient4',
#        'strIngredient5', 'strIngredient6', 'strIngredient7', 'strIngredient8',
#        'strIngredient9', 'strInstructions', 'strMeasure1', 'strMeasure10',
#        'strMeasure11', 'strMeasure12', 'strMeasure13', 'strMeasure14',
#        'strMeasure15', 'strMeasure2', 'strMeasure3', 'strMeasure4',
#        'strMeasure5', 'strMeasure6', 'strMeasure7', 'strMeasure8',
#        'strMeasure9', 'strVideo'],
#       dtype='object')

# %%
drinks_df = drinks_df.drop(columns=['Unnamed: 0','strInstructions', 'strMeasure1', 'strMeasure10',
       'strMeasure11', 'strMeasure12', 'strMeasure13', 'strMeasure14',
       'strMeasure15', 'strMeasure2', 'strMeasure3', 'strMeasure4',
       'strMeasure5', 'strMeasure6', 'strMeasure7', 'strMeasure8',
       'strMeasure9', 'strVideo'])

# %%
drinks_df = drinks_df.drop(columns=['strDrinkThumb', 'strGlass',
       'strIBA'])
drinks_df
# Out:
#                                  strDrink           strCategory  \
# 0    '57 Chevy with a White License Plate              Cocktail
# 1                          1-900-FUK-MEUP                  Shot
# 2                        110 in the shade                  Beer
# 3                  151 Florida Bushwacker  Milk / Float / Shake
# 4                             155 Belmont              Cocktail
# ..                                    ...                   ...
# 541                       Zippy's Revenge              Cocktail
# 542                        Zizi Coin-coin   Punch / Party Drink
# 543                                Zoksel     Soft Drink / Soda
# 544                             Zorbatini              Cocktail
# 545                                 Zorro          Coffee / Tea
#
#      strIngredient1 strIngredient10 strIngredient11 strIngredient12  \
# 0    Creme de Cacao             NaN             NaN             NaN
# ...

# %%
drinks_df.columns
# Out:
# Index(['strDrink', 'strCategory', 'strIngredient1', 'strIngredient10',
#        'strIngredient11', 'strIngredient12', 'strIngredient13',
#        'strIngredient14', 'strIngredient15', 'strIngredient2',
#        'strIngredient3', 'strIngredient4', 'strIngredient5', 'strIngredient6',
#        'strIngredient7', 'strIngredient8', 'strIngredient9'],
#       dtype='object')

# %%
all_items = []
for col in drinks_df.columns:
    for item in drinks_df[col]:
        all_items.append(item)

# %%
len(all_items)
# Out:
# 9282

# %%
all_items = [str(item) for item in all_items]

# %%
all_items = [item.lower() for item in all_items]

# %%
all_drinks_df = pd.DataFrame(all_items)
all_drinks_df
# Out:
#                                          0
# 0     '57 chevy with a white license plate
# 1                           1-900-fuk-meup
# 2                         110 in the shade
# 3                   151 florida bushwacker
# 4                              155 belmont
# ...                                    ...
# 9277                                   nan
# 9278                                   nan
# 9279                                   nan
# 9280                                   nan
# 9281                                   nan
#
# [9282 rows x 1 columns]

# %%
all_drinks_df = all_drinks_df.rename(columns = {0:'name'})

# %%
all_drinks_df = all_drinks_df.drop_duplicates()

# %%
all_drinks_df = all_drinks_df.reset_index(drop=True)

# %%
all_drinks_df = all_drinks_df[['name']]

# %%
all_drinks_df['name'] = all_drinks_df['name'].str.lower()

# %%
all_drinks_df['name'] = all_drinks_df['name'].str.replace('\d+', '')
# Out:
# /var/folders/6r/25t48ttd22sf4h8zsln4prl80000gn/T/ipykernel_13664/1922824730.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   all_drinks_df['name'] = all_drinks_df['name'].str.replace('\d+', '')

# %%
all_drinks_df['name'] = all_drinks_df['name'].str.replace('[^A-Za-z ]+', '')
# Out:
# /var/folders/6r/25t48ttd22sf4h8zsln4prl80000gn/T/ipykernel_13664/3640942155.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   all_drinks_df['name'] = all_drinks_df['name'].str.replace('[^A-Za-z ]+', '')

# %%
all_drinks_df = all_drinks_df.drop_duplicates()

# %%
all_drinks_df[0:10]
# Out:
#                                 name
# 0   chevy with a white license plate
# 1                            fukmeup
# 2                       in the shade
# 3                 florida bushwacker
# 4                            belmont
# 5                        k nightmare
# 6
# 7                           wise men
# 8          mile long island iced tea
# 9                               gone

# %%
all_drinks_df.drop([6,9])
# Out:
#                                   name
# 0     chevy with a white license plate
# 1                              fukmeup
# 2                         in the shade
# 3                   florida bushwacker
# 4                              belmont
# ..                                 ...
# 855                    marjoram leaves
# 856                  minisnickers bars
# 857                           lavender
# 858                       black pepper
# 859                             fresca
#
# [853 rows x 1 columns]

# %%
all_drinks_df = all_drinks_df.drop([6,9,855,856,857,858])

# %%
all_drinks_df
# Out:
#                                   name
# 0     chevy with a white license plate
# 1                              fukmeup
# 2                         in the shade
# 3                   florida bushwacker
# 4                              belmont
# ..                                 ...
# 851                   cherry grenadine
# 852                   caramel coloring
# 853                             pepper
# 854                           cherries
# 859                             fresca
#
# [849 rows x 1 columns]

# %%
all_drinks_df = all_drinks_df.drop([852,853,854])

# %%
all_drinks_df
# Out:
#                                   name
# 0     chevy with a white license plate
# 1                              fukmeup
# 2                         in the shade
# 3                   florida bushwacker
# 4                              belmont
# ..                                 ...
# 848                        oreo cookie
# 849                     whipping cream
# 850                    chocolate sauce
# 851                   cherry grenadine
# 859                             fresca
#
# [846 rows x 1 columns]

# %%
all_drinks_df = all_drinks_df.drop([848,849,850])

# %%
all_drinks_df[-50:]
# Out:
#                      name
# 800  blackcurrant cordial
# 801           olive brine
# 802       pineapple syrup
# 803        condensed milk
# 804                  salt
# 805           agave syrup
# 806               sherbet
# 807                aperol
# 808            mint syrup
# 809            cumin seed
# 810                 olive
# 811          daiquiri mix
# 812            pepsi cola
# 813                cloves
# 814           orange peel
# 815      peychaud bitters
# 816               curacao
# 817   blackcurrant squash
# 818              cardamom
# 819           celery salt
# 820          lillet blanc
# 821      cream of coconut
# 822     maraschino cherry
# 823         hot chocolate
# 824                cherry
# 825         licorice root
# 826     fresh lemon juice
# 827      almond flavoring
# 828  worcestershire sauce
# 829         creme de mure
# 830               vanilla
# 831    peppermint extract
# 832            st germain
# 833             dr pepper
# ...

# %%
all_drinks_df = all_drinks_df.drop([801,802,804,805,806,808,809,810,
                                 813,814,817,
818,
819,
820,
821,
822,
824,
825,
827,
828,
829,
830,
831,
834,
836,
837,
838,
839,
840,
841,
843,
844,
846,
847,
851
])

# %%
all_drinks_df[-50:]
# Out:
#                      name
# 765              drambuie
# 766          orgeat syrup
# 767             tropicana
# 768                 honey
# 769       pina colada mix
# 770     angostura bitters
# 771          coconut milk
# 772         pink lemonade
# 773        cherry liqueur
# 774            lime vodka
# 775        lemonlime soda
# 776        powdered sugar
# 777              anisette
# 778              cinnamon
# 779               aquavit
# 780             coriander
# 781           maple syrup
# 782   schweppes russchian
# 783                 fruit
# 784                 surge
# 785          rumple minze
# 786    strawberry liqueur
# 787                 anise
# 788     yellow chartreuse
# 789                kummel
# 790             egg white
# 791           guava juice
# 792               apricot
# 793         whipped cream
# 794              allspice
# 795          gold tequila
# 796    lime juice cordial
# 797   passion fruit syrup
# 798                 cream
# ...

# %%
all_drinks_df = all_drinks_df.drop([
768,
776,
777,
778,
780,
787,
788,
789,
790,
792,
793,
794,
797,
799])

# %%
all_drinks_df
# Out:
#                                   name
# 0     chevy with a white license plate
# 1                              fukmeup
# 2                         in the shade
# 3                   florida bushwacker
# 4                              belmont
# ..                                 ...
# 833                          dr pepper
# 835                      orange spiral
# 842                   fresh lime juice
# 845                      melon liqueur
# 859                             fresca
#
# [794 rows x 1 columns]

# %%
all_drinks_df['length'] = all_drinks_df['name'].str.len()

# %%
all_drinks_df = all_drinks_df[all_drinks_df['length'] >= 4]

# %%
all_drinks_df = all_drinks_df.drop(columns=['length'])

# %%
all_drinks_df
# Out:
#                                   name
# 0     chevy with a white license plate
# 1                              fukmeup
# 2                         in the shade
# 3                   florida bushwacker
# 4                              belmont
# ..                                 ...
# 833                          dr pepper
# 835                      orange spiral
# 842                   fresh lime juice
# 845                      melon liqueur
# 859                             fresca
#
# [777 rows x 1 columns]

# %%
all_drinks_df[635:685]
# Out:
#                            name
# 657                       cider
# 658                      whisky
# 659                    hot damn
# 660                 grape juice
# 661                  lemon peel
# 662               irish whiskey
# 663                apple brandy
# 665           blackberry brandy
# 666                      ginger
# 667             creme de cassis
# 668             cranberry vodka
# 669                kiwi liqueur
# 670                        kiwi
# 671                     koolaid
# 672                       mango
# 673            carbonated water
# 674                    espresso
# 675                        mint
# 676                    absinthe
# 677               cherry brandy
# 678                 lemon juice
# 679                      sprite
# 680                        port
# 681               coffee brandy
# 682               black sambuca
# 683                 sugar syrup
# 684             raspberry vodka
# 685                  frangelico
# ...

# %%
all_drinks_df = all_drinks_df.drop([
659,
661,
666,
670,
672,
675,
695,
708])

# %%
all_drinks_df[708:758]
# Out:
#                       name
# 740  butterscotch schnapps
# 741     maraschino liqueur
# 742        vanilla extract
# 743             ginger ale
# 744          peach bitters
# 745         absolut peppar
# 746           sarsaparilla
# 747      raspberry liqueur
# 748            benedictine
# 749              pineapple
# 750            fruit juice
# 751            tonic water
# 752  carbonated soft drink
# 753             corn syrup
# 754                 butter
# 755            halfandhalf
# 756           peach brandy
# 757      tennessee whiskey
# 758                  jello
# 759                   anis
# 760       green chartreuse
# 761          grain alcohol
# 762              apfelkorn
# 763           bitter lemon
# 764                 papaya
# 765               drambuie
# 766           orgeat syrup
# 767              tropicana
# 769        pina colada mix
# 770      angostura bitters
# 771           coconut milk
# 772          pink lemonade
# 773         cherry liqueur
# ...

# %%
all_drinks_df = all_drinks_df.drop([
742,
749,
753,
754,
755,
758,
759,
763,
764,
766,
781,
783
])

# %%
all_drinks_df.reset_index(drop=True,inplace=True)

# %%
all_drinks_df
# Out:
#                                   name
# 0     chevy with a white license plate
# 1                              fukmeup
# 2                         in the shade
# 3                   florida bushwacker
# 4                              belmont
# ..                                 ...
# 752                          dr pepper
# 753                      orange spiral
# 754                   fresh lime juice
# 755                      melon liqueur
# 756                             fresca
#
# [757 rows x 1 columns]

# %%
all_drinks_df = all_drinks_df.drop([
753
])

# %%
all_drinks_df
# Out:
#                                   name
# 0     chevy with a white license plate
# 1                              fukmeup
# 2                         in the shade
# 3                   florida bushwacker
# 4                              belmont
# ..                                 ...
# 751                         st germain
# 752                          dr pepper
# 754                   fresh lime juice
# 755                      melon liqueur
# 756                             fresca
#
# [756 rows x 1 columns]

# %%
all_drinks_df.reset_index(drop=True,inplace=True)

# %%
new_drinks = ['coca cola', 'cola', 'pepsi','coffee','pepsi cola','bintang',
                  'budweiser','red wine', 'mountain dew','coke','screwdriver', 'red bull', 'redbull', 'starbucks coffee']

# %%
new_drinks = pd.DataFrame(new_drinks)

# %%
new_drinks.rename(columns={0:'name'}, inplace=True)

# %%
all_drinks_df = pd.concat([all_drinks_df,new_drinks])

# %%
all_drinks_df.to_csv('../data/stripped_drinks.csv', index=False)

# %%
#all_drinks_df.to_csv()

# %%
    verified_queries = ['cheeseburger','burger','pizza','fried chicken','ice cream sundae','fuyung hai','screwdriver','redbull','ice cream',
                       'loaded baked potato', 'roasted vegetables','strawberry cake','hamburger','subway','potato chips','french fries','salad',
                       'coca cola', 'pepsi cola', 'redbull', 'red bull','mountain dew','starbucks coffee','baskin robbins sundae','chicken burger',
                        'grill chicken sandwich','beef burger','singapore fried noodle','fried rice','ayam bakar taliwang','chicken satay',
                        'bacon  fried eggs','mug of tea or coffee','fish and chips','scampi and chips','bangers and mash','mashed potatoes and gravy',
                       'british beef burger and chips','traditional british beef burger with cheddar','chicken sandwich', 'blt sandwich','tuna mayo sandwich',
                        'cheese   tomato sandwich','milkshake', 'tea coffee', 'burgers', 'double burger','bacon and egg burger','onion rings','apple pie']

# %%
import pandas as pd
df = pd.DataFrame({'name':verified_queries})

# %%
df
# Out:
#                                             name
# 0                                   cheeseburger
# 1                                         burger
# 2                                          pizza
# 3                                  fried chicken
# 4                               ice cream sundae
# 5                                     fuyung hai
# 6                                    screwdriver
# 7                                        redbull
# 8                                      ice cream
# 9                            loaded baked potato
# 10                            roasted vegetables
# 11                               strawberry cake
# 12                                     hamburger
# 13                                        subway
# 14                                  potato chips
# 15                                  french fries
# 16                                         salad
# 17                                     coca cola
# ...

# %%
df.to_csv('../data/verified.csv', index=False)
